# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt("./test_intersection_geology.txt",skip_header=1,delimiter=",",dtype=None,encoding=None)
data = np.array(list(map(list,data)))
units=data[:,0]
s=np.array(list(map(float,data[:,1])))
x=np.array(list(map(float,data[:,2])))
y=np.array(list(map(float,data[:,3])))
z=np.array(list(map(float,data[:,4])))

data2 = np.genfromtxt("./test_intersection_profile.txt",skip_header=1,delimiter=",",dtype=None,encoding=None)
data2 = np.array(list(map(list,data2)))
#units=data[:,0]
x2=np.array(list(map(float,data2[:,3])))
y2=np.array(list(map(float,data2[:,4])))
dd2=np.array(list(map(float,data2[:,5])))
z2=np.array(list(map(float,data2[:,6])))

xref=np.argmax(x)
print(xref)

d=((x-x[xref])**2+(y-y[xref])**2)**0.5
d2=((x2-x2[0])**2+(y2-y2[0])**2)**0.5
plt.scatter(dd2,z2)
plt.scatter(d,z)
# Out:
# 7710
